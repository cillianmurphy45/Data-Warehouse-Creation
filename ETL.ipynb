# %% [markdown]
# # Creating an Extract, Transform and Load process

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import mysql.connector
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Data

# %%
car_sales = pd.read_csv("Data/Cleaned_Car_Sales_Data.csv")

# %% [markdown]
# ### Creating Connection to Database

# %%
conn = mysql.connector.connect(
    host=os.getenv("DB_HOST"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD"),
    database=os.getenv("DB_NAME")
)

cur = conn.cursor()

# %% [markdown]
# ### Creating Tables
# - Fact_Tables_Sales
# - Dim_Dealer
# - Dim_Region
# - Dim_Date
# - Dim_Car
# - Dim_Customer

# %% [markdown]
# ### Dim_Customer Table

# %%
customer_data = car_sales[['Customer_Name', 'Gender']]

# %%
cur.execute("""
CREATE TABLE IF NOT EXISTS Dim_Customer (
            Customer_ID INT AUTO_INCREMENT PRIMARY KEY,
            Customer_Name VARCHAR(255),
            Gender VARCHAR(20)
            );""")

for i, cust_row in customer_data.iterrows():
    cust_sql = """INSERT INTO Dim_Customer (Customer_Name, Gender) VALUES (%s, %s)"""

    cust_values = tuple(cust_row)

    cur.execute(cust_sql, cust_values)

conn.commit()

# %% [markdown]
# ### Dim_Car Table

# %%
car_data = car_sales[['Car_Manufacturer','Car_Model', 'Engine_Type','Transmission', 'Colour','Body_Style']]

# %%
car_data = car_data.drop_duplicates().reset_index(drop=True)

# %%
cur.execute("""
    CREATE TABLE IF NOT EXISTS Dim_Car (
                Car_ID INT AUTO_INCREMENT PRIMARY KEY,
                Car_Manufacturer VARCHAR(50),
                Car_Model VARCHAR(50),
                Engine_Type VARCHAR(50),
                Transmission VARCHAR(50),
                Colour VARCHAR(50),
                Body_Style VARCHAR(50)
            );
    """)

for i, car_row in car_data.iterrows():
    car_sql = """INSERT INTO Dim_Car (Car_Manufacturer, Car_Model, Engine_Type, Transmission,Colour, Body_Style) VALUES (%s, %s, %s, %s, %s, %s)"""

    car_values = tuple(car_row)

    cur.execute(car_sql, car_values)

conn.commit()

# %% [markdown]
# ### Dim_Date

# %%
car_sales["Sale_Date"] = pd.to_datetime(car_sales["Sale_Date"])

# %%
date_data = pd.DataFrame(car_sales["Sale_Date"].drop_duplicates().reset_index(drop=True))

# %%
date_data["Year"] = date_data["Sale_Date"].dt.year
date_data["Quarter"] = date_data["Sale_Date"].dt.quarter
date_data["Month"] = date_data["Sale_Date"].dt.month_name()
date_data["Day"] = date_data["Sale_Date"].dt.day_name()

# %%
date_data["Sale_Date"] = date_data["Sale_Date"].dt.date

# %%
cur.execute("""
    CREATE TABLE IF NOT EXISTS Dim_Date (
                Date_ID INT AUTO_INCREMENT PRIMARY KEY,
                Sale_Date DATE,
                Year VARCHAR(50),
                Quarter INT,
                Month VARCHAR(50),
                Day VARCHAR(50)
            );
    """)

for i, date_row in date_data.iterrows():
    date_sql = """INSERT INTO Dim_Date (Sale_Date, Year, Quarter, Month,Day) VALUES (%s, %s, %s, %s, %s)"""

    date_values = tuple(date_row)

    cur.execute(date_sql, date_values)

conn.commit()

# %% [markdown]
# ### Dim_Region

# %%
region_data = car_sales[['Dealer_Region', 'Dealer_State']].drop_duplicates().reset_index(drop=True)

# %%
cur.execute("""
    CREATE TABLE IF NOT EXISTS Dim_Region (
                Region_ID INT AUTO_INCREMENT PRIMARY KEY,
                Dealer_Region VARCHAR(50),
                Dealer_State VARCHAR(50)
            );
    """)

for i, region_row in region_data.iterrows():
    region_sql = """INSERT INTO Dim_Region (Dealer_Region, Dealer_State) VALUES (%s, %s)"""

    region_values = tuple(region_row)

    cur.execute(region_sql, region_values)

conn.commit()

# %% [markdown]
# ### Dim_Dealer

# %%
dealer_data = car_sales[['Dealer_ID', "Dealer_Name"]].drop_duplicates().reset_index(drop=True)

# %%
dealer_data
# Out:
#    Dealer_ID                                      Dealer_Name
# 0         D1              Buddy Storbeck's Diesel Service Inc
# 1         D2                                 C & M Motors Inc
# 2         D3                                      Capitol KIA
# 3         D4                           Chrysler of Tri-Cities
# 4         D5                                Chrysler Plymouth
# 5         D6                                    Classic Chevy
# 6         D7                          Clay Johnson Auto Sales
# 7         D8                                        U-Haul CO
# 8         D9                             Rabun Used Car Sales
# 9        D10                                    Race Car Help
# 10       D11                                 Saab-Belle Dodge
# 11       D12                Scrivener Performance Engineering
# 12       D13                               Diehl Motor CO Inc
# 13       D14                             Star Enterprises Inc
# 14       D15                                    Suburban Ford
# 15       D16                               Tri-State Mack Inc
# 16       D17  Progressive Shippers Cooperative Association No
# 17       D18                   Ryder Truck Rental and Leasing
# 18       D19                            Enterprise Rent A Car
# 19       D20                       Gartner Buick Hyundai Saab
# 20       D21                              Hatfield Volkswagen
# 21       D22                                  Iceberg Rentals
# 22       D23                     McKinney Dodge Chrysler Jeep
# 23       D24                      Motor Vehicle Branch Office
# 24       D25                                   Nebo Chevrolet
# 25       D26                  New Castle Ford Lincoln Mercury
# 26       D27                                  Pars Auto Sales
# 27       D28            Pitre Buick-Pontiac-Gmc of Scottsdale

# %%
cur.execute("""
    CREATE TABLE IF NOT EXISTS Dim_Dealer (
                Dealer_ID VARCHAR(10) PRIMARY KEY,
                Dealer_Name VARCHAR(200)
            );
    """)

for i, dealer_row in dealer_data.iterrows():
    dealer_sql = """INSERT INTO Dim_Dealer (Dealer_ID, Dealer_Name) VALUES (%s, %s)"""

    dealer_values = tuple(dealer_row)

    cur.execute(dealer_sql, dealer_values)

conn.commit()

# %% [markdown]
# ### Creating Fact Sales Table

# %%
car_sales
# Out:
#              Car_ID  Sale_Date Customer_Name  Gender  Annual_Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia  Female        1480000
# 2      C_CND_000003 2022-01-02        Gianna  Female        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace  Female        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma  Female         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name Car_Manufacturer   Car_Model  \
# 0      Buddy Storbeck's Diesel Service Inc             Ford  Expedition
# 1                         C & M Motors Inc            Dodge     Durango
# 2                              Capitol KIA         Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities           Toyota      Celica
# 4                        Chrysler Plymouth            Acura          TL
# ...                                    ...              ...         ...
# 23901                     C & M Motors Inc         Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing        Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities              BMW        328i
# 23904                    Chrysler Plymouth        Chevrolet       Metro
# 23905                      Pars Auto Sales            Lexus       ES300
#
#                     Engine_Type Transmission      Colour  Sale_Price  \
# 0      Double Overhead Camshaft         Auto       Black       26000
# 1      Double Overhead Camshaft         Auto       Black       19000
# 2             Overhead Camshaft       Manual         Red       31500
# 3             Overhead Camshaft       Manual  Pale White       14000
# 4      Double Overhead Camshaft         Auto         Red       24500
# ...                         ...          ...         ...         ...
# 23901         Overhead Camshaft       Manual         Red       12000
# 23902  Double Overhead Camshaft         Auto       Black       16000
# 23903         Overhead Camshaft       Manual         Red       21000
# 23904  Double Overhead Camshaft         Auto       Black       31000
# 23905  Double Overhead Camshaft         Auto  Pale White       27500
#
#       Dealer_ID Body_Style  Customer_Phone_Number Dealer_Region  \
# 0            D1        SUV                8264678    Middletown
# 1            D2        SUV                6848189        Aurora
# 2            D3  Passenger                7298798    Greenville
# 3            D4        SUV                6257557         Pasco
# 4            D5  Hatchback                7081483    Janesville
# ...         ...        ...                    ...           ...
# 23901        D2  Passenger                8583598         Pasco
# 23902       D18    Hardtop                7914229    Middletown
# 23903        D4      Sedan                7659127    Scottsdale
# 23904        D5  Passenger                6030764        Austin
# 23905       D27    Hardtop                7020564    Middletown
#
#          Dealer_State
# 0                Ohio
# 1            Colarado
# 2      South Carolina
# 3          Washington
# 4           Wisconsin
# ...               ...
# 23901      Washington
# 23902            Ohio
# 23903         Arizona
# 23904           Texas
# 23905            Ohio
#
# [23906 rows x 17 columns]
